# %% [markdown]
# ## Исследование надёжности заёмщиков
#
# Заказчик — кредитный отдел банка. Нужно разобраться, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок. Входные данные от банка — статистика о платёжеспособности клиентов.
#
# Результаты исследования будут учтены при построении модели **кредитного скоринга** — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.

# %% [markdown]
# ### Шаг 1. Откройте файл с данными и изучите общую информацию.

# %%
from pymystem3 import Mystem
import pandas as pd
import collections

# %%
# data = pd.read_csv('data.csv') #nrows = 5
data = pd.read_csv('/datasets/data.csv') # код ревьюера
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
# children            21525 non-null int64
# days_employed       19351 non-null float64
# dob_years           21525 non-null int64
# education           21525 non-null object
# education_id        21525 non-null int64
# family_status       21525 non-null object
# family_status_id    21525 non-null int64
# gender              21525 non-null object
# income_type         21525 non-null object
# debt                21525 non-null int64
# total_income        19351 non-null float64
# purpose             21525 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %%
data.head(3)
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1   -8437.673028         42    высшее             0
# 1         1   -4024.803754         36   среднее             1
# 2         0   -5623.422610         33   Среднее             1
#
#      family_status  family_status_id gender income_type  debt   total_income  \
# 0  женат / замужем                 0      F   сотрудник     0  253875.639453
# 1  женат / замужем                 0      F   сотрудник     0  112080.014102
# 2  женат / замужем                 0      M   сотрудник     0  145885.952297
#
#                    purpose
# 0            покупка жилья
# 1  приобретение автомобиля
# 2            покупка жилья

# %%
data.groupby('income_type').count()
# Out:
#                  children  days_employed  dob_years  education  education_id  \
# income_type
# безработный             2              2          2          2             2
# в декрете               1              1          1          1             1
# госслужащий          1459           1312       1459       1459          1459
# компаньон            5085           4577       5085       5085          5085
# пенсионер            3856           3443       3856       3856          3856
# предприниматель         2              1          2          2             2
# сотрудник           11119          10014      11119      11119         11119
# студент                 1              1          1          1             1
#
#                  family_status  family_status_id  gender   debt  total_income  \
# income_type
# безработный                  2                 2       2      2             2
# в декрете                    1                 1       1      1             1
# госслужащий               1459              1459    1459   1459          1312
# компаньон                 5085              5085    5085   5085          4577
# пенсионер                 3856              3856    3856   3856          3443
# предприниматель              2                 2       2      2             1
# сотрудник                11119             11119   11119  11119         10014
# студент                      1                 1       1      1             1
#
#                  purpose
# income_type
# безработный            2
# в декрете              1
# госслужащий         1459
# компаньон           5085
# пенсионер           3856
# предприниматель        2
# сотрудник          11119
# студент                1

# %%
data.groupby('family_status').count()
# Out:
#                        children  days_employed  dob_years  education  \
# family_status
# Не женат / не замужем      2813           2525       2813       2813
# в разводе                  1195           1083       1195       1195
# вдовец / вдова              960            865        960        960
# гражданский брак           4177           3735       4177       4177
# женат / замужем           12380          11143      12380      12380
#
#                        education_id  family_status_id  gender  income_type  \
# family_status
# Не женат / не замужем          2813              2813    2813         2813
# в разводе                      1195              1195    1195         1195
# вдовец / вдова                  960               960     960          960
# гражданский брак               4177              4177    4177         4177
# женат / замужем               12380             12380   12380        12380
#
#                         debt  total_income  purpose
# family_status
# Не женат / не замужем   2813          2525     2813
# в разводе               1195          1083     1195
# вдовец / вдова           960           865      960
# гражданский брак        4177          3735     4177
# женат / замужем        12380         11143    12380

# %%
data.groupby('purpose').count()
# Out:
#                                         children  days_employed  dob_years  \
# purpose
# автомобили                                   478            421        478
# автомобиль                                   495            454        495
# высшее образование                           453            413        453
# дополнительное образование                   462            414        462
# жилье                                        647            587        647
# заняться высшим образованием                 496            440        496
# заняться образованием                        412            357        412
# на покупку автомобиля                        472            442        472
# на покупку подержанного автомобиля           479            437        479
# на покупку своего автомобиля                 505            452        505
# на проведение свадьбы                        777            685        777
# недвижимость                                 634            572        634
# образование                                  447            405        447
# операции с жильем                            653            579        653
# операции с коммерческой недвижимостью        651            581        651
# операции с недвижимостью                     676            615        676
# операции со своей недвижимостью              630            559        630
# покупка жилой недвижимости                   607            546        607
# покупка жилья                                647            595        647
# покупка жилья для сдачи                      653            588        653
# покупка жилья для семьи                      641            570        641
# покупка коммерческой недвижимости            664            597        664
# покупка недвижимости                         624            552        624
# покупка своего жилья                         620            574        620
# получение высшего образования                426            390        426
# получение дополнительного образования        447            396        447
# получение образования                        443            393        443
# приобретение автомобиля                      462            419        462
# профильное образование                       436            389        436
# ремонт жилью                                 612            542        612
# свадьба                                      797            721        797
# свой автомобиль                              480            428        480
# сделка с автомобилем                         455            409        455
# сделка с подержанным автомобилем             489            435        489
# строительство жилой недвижимости             626            580        626
# строительство недвижимости                   620            561        620
# строительство собственной недвижимости       635            560        635
# сыграть свадьбу                              774            693        774
#
#                                         education  education_id  \
# purpose
# автомобили                                    478           478
# автомобиль                                    495           495
# высшее образование                            453           453
# дополнительное образование                    462           462
# жилье                                         647           647
# заняться высшим образованием                  496           496
# заняться образованием                         412           412
# на покупку автомобиля                         472           472
# на покупку подержанного автомобиля            479           479
# на покупку своего автомобиля                  505           505
# на проведение свадьбы                         777           777
# недвижимость                                  634           634
# образование                                   447           447
# операции с жильем                             653           653
# операции с коммерческой недвижимостью         651           651
# операции с недвижимостью                      676           676
# операции со своей недвижимостью               630           630
# покупка жилой недвижимости                    607           607
# покупка жилья                                 647           647
# покупка жилья для сдачи                       653           653
# покупка жилья для семьи                       641           641
# покупка коммерческой недвижимости             664           664
# покупка недвижимости                          624           624
# покупка своего жилья                          620           620
# получение высшего образования                 426           426
# получение дополнительного образования         447           447
# получение образования                         443           443
# приобретение автомобиля                       462           462
# профильное образование                        436           436
# ремонт жилью                                  612           612
# свадьба                                       797           797
# свой автомобиль                               480           480
# сделка с автомобилем                          455           455
# сделка с подержанным автомобилем              489           489
# строительство жилой недвижимости              626           626
# строительство недвижимости                    620           620
# строительство собственной недвижимости        635           635
# сыграть свадьбу                               774           774
#
#                                         family_status  family_status_id  \
# purpose
# автомобили                                        478               478
# автомобиль                                        495               495
# высшее образование                                453               453
# дополнительное образование                        462               462
# жилье                                             647               647
# заняться высшим образованием                      496               496
# заняться образованием                             412               412
# на покупку автомобиля                             472               472
# на покупку подержанного автомобиля                479               479
# на покупку своего автомобиля                      505               505
# на проведение свадьбы                             777               777
# недвижимость                                      634               634
# образование                                       447               447
# операции с жильем                                 653               653
# операции с коммерческой недвижимостью             651               651
# операции с недвижимостью                          676               676
# операции со своей недвижимостью                   630               630
# покупка жилой недвижимости                        607               607
# покупка жилья                                     647               647
# покупка жилья для сдачи                           653               653
# покупка жилья для семьи                           641               641
# покупка коммерческой недвижимости                 664               664
# покупка недвижимости                              624               624
# покупка своего жилья                              620               620
# получение высшего образования                     426               426
# получение дополнительного образования             447               447
# получение образования                             443               443
# приобретение автомобиля                           462               462
# профильное образование                            436               436
# ремонт жилью                                      612               612
# свадьба                                           797               797
# свой автомобиль                                   480               480
# сделка с автомобилем                              455               455
# сделка с подержанным автомобилем                  489               489
# строительство жилой недвижимости                  626               626
# строительство недвижимости                        620               620
# строительство собственной недвижимости            635               635
# сыграть свадьбу                                   774               774
#
#                                         gender  income_type  debt  \
# purpose
# автомобили                                 478          478   478
# автомобиль                                 495          495   495
# высшее образование                         453          453   453
# дополнительное образование                 462          462   462
# жилье                                      647          647   647
# заняться высшим образованием               496          496   496
# заняться образованием                      412          412   412
# на покупку автомобиля                      472          472   472
# на покупку подержанного автомобиля         479          479   479
# на покупку своего автомобиля               505          505   505
# на проведение свадьбы                      777          777   777
# недвижимость                               634          634   634
# образование                                447          447   447
# операции с жильем                          653          653   653
# операции с коммерческой недвижимостью      651          651   651
# операции с недвижимостью                   676          676   676
# операции со своей недвижимостью            630          630   630
# покупка жилой недвижимости                 607          607   607
# покупка жилья                              647          647   647
# покупка жилья для сдачи                    653          653   653
# покупка жилья для семьи                    641          641   641
# покупка коммерческой недвижимости          664          664   664
# покупка недвижимости                       624          624   624
# покупка своего жилья                       620          620   620
# получение высшего образования              426          426   426
# получение дополнительного образования      447          447   447
# получение образования                      443          443   443
# приобретение автомобиля                    462          462   462
# профильное образование                     436          436   436
# ремонт жилью                               612          612   612
# свадьба                                    797          797   797
# свой автомобиль                            480          480   480
# сделка с автомобилем                       455          455   455
# сделка с подержанным автомобилем           489          489   489
# строительство жилой недвижимости           626          626   626
# строительство недвижимости                 620          620   620
# строительство собственной недвижимости     635          635   635
# сыграть свадьбу                            774          774   774
#
#                                         total_income
# purpose
# автомобили                                       421
# автомобиль                                       454
# высшее образование                               413
# дополнительное образование                       414
# жилье                                            587
# заняться высшим образованием                     440
# заняться образованием                            357
# на покупку автомобиля                            442
# на покупку подержанного автомобиля               437
# на покупку своего автомобиля                     452
# на проведение свадьбы                            685
# недвижимость                                     572
# образование                                      405
# операции с жильем                                579
# операции с коммерческой недвижимостью            581
# операции с недвижимостью                         615
# операции со своей недвижимостью                  559
# покупка жилой недвижимости                       546
# покупка жилья                                    595
# покупка жилья для сдачи                          588
# покупка жилья для семьи                          570
# покупка коммерческой недвижимости                597
# покупка недвижимости                             552
# покупка своего жилья                             574
# получение высшего образования                    390
# получение дополнительного образования            396
# получение образования                            393
# приобретение автомобиля                          419
# профильное образование                           389
# ремонт жилью                                     542
# свадьба                                          721
# свой автомобиль                                  428
# сделка с автомобилем                             409
# сделка с подержанным автомобилем                 435
# строительство жилой недвижимости                 580
# строительство недвижимости                       561
# строительство собственной недвижимости           560
# сыграть свадьбу                                  693

# %%
data.groupby('debt').count()
# Out:
#       children  days_employed  dob_years  education  education_id  \
# debt
# 0        19784          17780      19784      19784         19784
# 1         1741           1571       1741       1741          1741
#
#       family_status  family_status_id  gender  income_type  total_income  \
# debt
# 0             19784             19784   19784        19784         17780
# 1              1741              1741    1741         1741          1571
#
#       purpose
# debt
# 0       19784
# 1        1741

# %%
data.groupby('gender').count()
# Out:
#         children  days_employed  dob_years  education  education_id  \
# gender
# F          14236          12752      14236      14236         14236
# M           7288           6598       7288       7288          7288
# XNA            1              1          1          1             1
#
#         family_status  family_status_id  income_type   debt  total_income  \
# gender
# F               14236             14236        14236  14236         12752
# M                7288              7288         7288   7288          6598
# XNA                 1                 1            1      1             1
#
#         purpose
# gender
# F         14236
# M          7288
# XNA           1

# %%
data.dob_years.count()
# Out:
# 21525

# %% [markdown]
# ### Вывод

# %% [markdown]
# - Пропущены значения в **days_employed** и **total_income**, нужно будет обработать.
# - **education** - привести к одному формату
# - Поменять тип **days_employed** на целочисленный.
# - **debt** поменять тип на логический
# - **total_income** - поменять тип на целочисленный
# - Леммаризовать **purpose**

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# ### Обработка пропусков

# %% [markdown]
# Заполним отсутствующие значения **days_employed** медианой. Поскольку отрицательных дней не бывает, меняем знак где надо. Медиана выбрана потому что есть явно завышенные значения, и среднее арифметическое с учетом этого будет завышено тоже. Для **total_income** тоже выбираем медиану, поскольку средний доход достовернее показывать именно этим характерным значением.
#
# Причины пропусков не очень понятны возможно часть данных о работе и доходе просто потерялись где то.

# %%
data.days_employed = data.days_employed.abs() # меняем знак
data.days_employed.median() # смотрим на медиану
# Out:
# 2194.220566878695

# %%
data.days_employed.isna().sum() # количество пропущеных значений
# Out:
# 2174

# %%
data.days_employed = data.days_employed.fillna(data.days_employed.median()) # заполняем пропущенные значения
data.days_employed.isna().sum()
# Out:
# 0

# %%
data.total_income.median()
# Out:
# 145017.93753253992

# %%
data.total_income.isna().sum()
# Out:
# 2174

# %%
data.total_income = data.total_income.fillna(data.total_income.median())

# %%
data.total_income.isna().sum()
# Out:
# 0

# %% [markdown]
# Еще мы нашли ошибочные значения которые тоже было бы неплохо обработать:
# - явно завышенные (раз так в 100-200 значения в стоблце **days_employed**
# - завышенное количество семей у которых 20 детей, что скорее всего тоже ошибка
# - заемщик с неправильным **gender**
#
# Для замены ошибочных значений **days_employed**, поскольку большинство заемщиков с ошибочными данными это пенсионеры, можно выставить в столбец отработанных дней значение соответствующее 30-40 годам, для семей с 20 детьми - поставим 2 детей, так как скорее всего ошибка возникла из-за добавления нуля. Заемщика с неправильным **gender** удалим, потому что он единственный и его удаление значимо не повлияет на исследование данных.

# %%
data['employed_year'] = (data.days_employed/365).astype('int64')
data[data['employed_year']>(data['dob_years'])].groupby('income_type').count()
# Out:
#              children  days_employed  dob_years  education  education_id  \
# income_type
# безработный         2              2          2          2             2
# госслужащий         6              6          6          6             6
# компаньон          18             18         18         18            18
# пенсионер        3446           3446       3446       3446          3446
# сотрудник          49             49         49         49            49
#
#              family_status  family_status_id  gender  debt  total_income  \
# income_type
# безработный              2                 2       2     2             2
# госслужащий              6                 6       6     6             6
# компаньон               18                18      18    18            18
# пенсионер             3446              3446    3446  3446          3446
# сотрудник               49                49      49    49            49
#
#              purpose  employed_year
# income_type
# безработный        2              2
# госслужащий        6              6
# компаньон         18             18
# пенсионер       3446           3446
# сотрудник         49             49

# %%
data[data['employed_year']>(data['dob_years'])].income_type.value_counts()
# Out:
# пенсионер      3446
# сотрудник        49
# компаньон        18
# госслужащий       6
# безработный       2
# Name: income_type, dtype: int64

# %%
data.days_employed.median()
# Out:
# 2194.220566878695

# %%
data.days_employed.mean()
# Out:
# 60378.0327334873

# %%
data.loc[data['days_employed'] > data['dob_years']*365, 'days_employed'] = 35*365

# %% [markdown]
# Прикинул что в среднем пенсионер проработает лет 35 до пенсии (может и больше

# %%
data.days_employed.median()
# Out:
# 2194.220566878695

# %%
data.days_employed.mean()
# Out:
# 4046.2491016855333

# %%
data.loc[data['children'] == 20, 'children'] = 2 # меняем 20 на 2

# %%
data.groupby('children').count()
# Out:
#           days_employed  dob_years  education  education_id  family_status  \
# children
# -1                   47         47         47            47             47
#  0                14149      14149      14149         14149          14149
#  1                 4818       4818       4818          4818           4818
#  2                 2131       2131       2131          2131           2131
#  3                  330        330        330           330            330
#  4                   41         41         41            41             41
#  5                    9          9          9             9              9
#
#           family_status_id  gender  income_type   debt  total_income  purpose  \
# children
# -1                      47      47           47     47            47       47
#  0                   14149   14149        14149  14149         14149    14149
#  1                    4818    4818         4818   4818          4818     4818
#  2                    2131    2131         2131   2131          2131     2131
#  3                     330     330          330    330           330      330
#  4                      41      41           41     41            41       41
#  5                       9       9            9      9             9        9
#
#           employed_year
# children
# -1                   47
#  0                14149
#  1                 4818
#  2                 2131
#  3                  330
#  4                   41
#  5                    9

# %%
data = data[data['gender'] != 'XNA']
data.groupby('gender').count()
# Out:
#         children  days_employed  dob_years  education  education_id  \
# gender
# F          14236          14236      14236      14236         14236
# M           7288           7288       7288       7288          7288
#
#         family_status  family_status_id  income_type   debt  total_income  \
# gender
# F               14236             14236        14236  14236         14236
# M                7288              7288         7288   7288          7288
#
#         purpose  employed_year
# gender
# F         14236          14236
# M          7288           7288

# %% [markdown]
# ### Вывод

# %% [markdown]
# Обработали пропуски характерным значением (медианой). Обработали ошибочные значения.

# %% [markdown]
# ### Замена типа данных

# %% [markdown]
# **total_income** и **days_employed** меняем на целочисленный, **debt** меняем на логический.

# %%
data.total_income = data.total_income.astype('int64')
data.days_employed = data.days_employed.astype('int64')
data.debt = data.debt.astype('bool')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21524 entries, 0 to 21524
# Data columns (total 13 columns):
# children            21524 non-null int64
# days_employed       21524 non-null int64
# dob_years           21524 non-null int64
# education           21524 non-null object
# education_id        21524 non-null int64
# family_status       21524 non-null object
# family_status_id    21524 non-null int64
# gender              21524 non-null object
# income_type         21524 non-null object
# debt                21524 non-null bool
# total_income        21524 non-null int64
# purpose             21524 non-null object
# employed_year       21524 non-null int64
# dtypes: bool(1), int64(7), object(5)
# memory usage: 2.2+ MB

# %% [markdown]
# ### Вывод

# %% [markdown]
# Поменяли, получилось! Для замены типа данных используется метод pandas astype(), потому что он хорошо и корректно меняет тип данных.

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# Для того что бы обработать дубликаты приведем значения столбца **education** к одному формату.
# Поменяем отричательное количество детей в столбце **children** на положительное.
#
# Будем использовать метод duplicated() и метод sum() для поиска и подсчета количества дубликатов.
# Для удаления дупликатов будем использовать метод drop_duplicates()
#
# Причины появления дубликатов - ошибки в исходных данных, разные форматы значений **education**, **children**.

# %%
data.groupby('education').count()
# Out:
#                      children  days_employed  dob_years  education_id  \
# education
# ВЫСШЕЕ                    274            274        274           274
# Высшее                    268            268        268           268
# НАЧАЛЬНОЕ                  17             17         17            17
# НЕОКОНЧЕННОЕ ВЫСШЕЕ        29             29         29            29
# Начальное                  15             15         15            15
# Неоконченное высшее        47             47         47            47
# СРЕДНЕЕ                   772            772        772           772
# Среднее                   711            711        711           711
# УЧЕНАЯ СТЕПЕНЬ              1              1          1             1
# Ученая степень              1              1          1             1
# высшее                   4718           4718       4718          4718
# начальное                 250            250        250           250
# неоконченное высшее       667            667        667           667
# среднее                 13750          13750      13750         13750
# ученая степень              4              4          4             4
#
#                      family_status  family_status_id  gender  income_type  \
# education
# ВЫСШЕЕ                         274               274     274          274
# Высшее                         268               268     268          268
# НАЧАЛЬНОЕ                       17                17      17           17
# НЕОКОНЧЕННОЕ ВЫСШЕЕ             29                29      29           29
# Начальное                       15                15      15           15
# Неоконченное высшее             47                47      47           47
# СРЕДНЕЕ                        772               772     772          772
# Среднее                        711               711     711          711
# УЧЕНАЯ СТЕПЕНЬ                   1                 1       1            1
# Ученая степень                   1                 1       1            1
# высшее                        4718              4718    4718         4718
# начальное                      250               250     250          250
# неоконченное высшее            667               667     667          667
# среднее                      13750             13750   13750        13750
# ученая степень                   4                 4       4            4
#
#                       debt  total_income  purpose  employed_year
# education
# ВЫСШЕЕ                 274           274      274            274
# Высшее                 268           268      268            268
# НАЧАЛЬНОЕ               17            17       17             17
# НЕОКОНЧЕННОЕ ВЫСШЕЕ     29            29       29             29
# Начальное               15            15       15             15
# Неоконченное высшее     47            47       47             47
# СРЕДНЕЕ                772           772      772            772
# Среднее                711           711      711            711
# УЧЕНАЯ СТЕПЕНЬ           1             1        1              1
# Ученая степень           1             1        1              1
# высшее                4718          4718     4718           4718
# начальное              250           250      250            250
# неоконченное высшее    667           667      667            667
# среднее              13750         13750    13750          13750
# ученая степень           4             4        4              4

# %%
data['education'] = data['education'].str.lower()
data.groupby('education').count()
# Out:
#                      children  days_employed  dob_years  education_id  \
# education
# высшее                   5260           5260       5260          5260
# начальное                 282            282        282           282
# неоконченное высшее       743            743        743           743
# среднее                 15233          15233      15233         15233
# ученая степень              6              6          6             6
#
#                      family_status  family_status_id  gender  income_type  \
# education
# высшее                        5260              5260    5260         5260
# начальное                      282               282     282          282
# неоконченное высшее            743               743     743          743
# среднее                      15233             15233   15233        15233
# ученая степень                   6                 6       6            6
#
#                       debt  total_income  purpose  employed_year
# education
# высшее                5260          5260     5260           5260
# начальное              282           282      282            282
# неоконченное высшее    743           743      743            743
# среднее              15233         15233    15233          15233
# ученая степень           6             6        6              6

# %%
data.children = data.children.abs()

# %%
data.duplicated().sum()
# Out:
# 71

# %%
data = data.drop_duplicates()
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Вывод

# %% [markdown]
# Мы удалили найденные дубликаты. После лемматизации нужно будет повторить процесс поиска и удалить снова.

# %% [markdown]
# ### Лемматизация

# %% [markdown]
# Применим лемматизацию для сортировки раздувшегося списка целей. разобьем на следующие категории: автомобиль, образование, свадьба, и жилье. Жилье дополнительно разобьем на покупку, ремонт и стоительство.
#
# Для применения функции к данным будем использовать метод map().

# %%
collections.Counter(data['purpose'])
# Out:
# Counter({'покупка жилья': 646,
#          'приобретение автомобиля': 461,
#          'дополнительное образование': 460,
#          'сыграть свадьбу': 765,
#          'операции с жильем': 652,
#          'образование': 447,
#          'на проведение свадьбы': 768,
#          'покупка жилья для семьи': 638,
#          'покупка недвижимости': 620,
#          'покупка коммерческой недвижимости': 661,
#          'покупка жилой недвижимости': 606,
#          'строительство собственной недвижимости': 635,
#          'недвижимость': 633,
#          'строительство недвижимости': 619,
#          'на покупку подержанного автомобиля': 478,
#          'на покупку своего автомобиля': 505,
#          'операции с коммерческой недвижимостью': 650,
#          'строительство жилой недвижимости': 624,
#          'жилье': 646,
#          'операции со своей недвижимостью': 627,
#          'автомобили': 478,
#          'заняться образованием': 408,
#          'сделка с подержанным автомобилем': 486,
#          'получение образования': 442,
#          'автомобиль': 494,
#          'свадьба': 791,
#          'получение дополнительного образования': 446,
#          'покупка своего жилья': 620,
#          'операции с недвижимостью': 675,
#          'получение высшего образования': 426,
#          'свой автомобиль': 478,
#          'сделка с автомобилем': 455,
#          'профильное образование': 436,
#          'высшее образование': 452,
#          'покупка жилья для сдачи': 651,
#          'на покупку автомобиля': 471,
#          'ремонт жилью': 607,
#          'заняться высшим образованием': 496})

# %%
def lemmat(text):

    t1 = m.lemmatize(text)
    if 'автомобиль' in t1: return 'автомобиль'
    if 'образование' in t1: return 'образование'
    if 'свадьба' in t1: return 'свадьба'
    if 'жилье' or 'недвижимость' in t1: 
        if 'покупка' in t1: return 'покупка жилья'
        elif 'ремонт' in t1: return 'ремонт жилья'
        elif 'строительство' in t1: return 'строительство жилья'
        else: return 'покупка жилья'
    

m = Mystem()
data['purpose'] = data['purpose'].map(lemmat)

# %%
collections.Counter(data['purpose'])
# Out:
# Counter({'покупка жилья': 8325,
#          'автомобиль': 4306,
#          'образование': 4013,
#          'свадьба': 2324,
#          'строительство жилья': 1878,
#          'ремонт жилья': 607})

# %%
data.groupby('purpose').count()
# Out:
#                      children  days_employed  dob_years  education  \
# purpose
# автомобиль               4306           4306       4306       4306
# образование              4013           4013       4013       4013
# покупка жилья            8325           8325       8325       8325
# ремонт жилья              607            607        607        607
# свадьба                  2324           2324       2324       2324
# строительство жилья      1878           1878       1878       1878
#
#                      education_id  family_status  family_status_id  gender  \
# purpose
# автомобиль                   4306           4306              4306    4306
# образование                  4013           4013              4013    4013
# покупка жилья                8325           8325              8325    8325
# ремонт жилья                  607            607               607     607
# свадьба                      2324           2324              2324    2324
# строительство жилья          1878           1878              1878    1878
#
#                      income_type  debt  total_income  employed_year
# purpose
# автомобиль                  4306  4306          4306           4306
# образование                 4013  4013          4013           4013
# покупка жилья               8325  8325          8325           8325
# ремонт жилья                 607   607           607            607
# свадьба                     2324  2324          2324           2324
# строительство жилья         1878  1878          1878           1878

# %%
data.duplicated().sum()
# Out:
# 254

# %%
data = data.drop_duplicates()
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Вывод

# %% [markdown]
# Лемматизация удалась. Дубликаты появившиеся из-за нее, почищены!

# %% [markdown]
# ### Категоризация данных

# %% [markdown]
# Для последующих вопросов, разобьем заемщиков по категориям по их доходу. Для вопроса про детей категоризуем по количеству детей.

# %%
def inc_group(income):
    if income <= 80000:
        return 'до 80к'
    elif 80001 <= income <= 100000:
        return 'от 80к до 100к'
    elif 100001 <= income <= 120000:
        return 'от 100к до 120к'
    elif 120001 <= income <= 130000:
        return 'от 120к до 130к'
    elif 130001 <= income <= 140000:
        return 'от 130к до 140к'
    elif 140001 <= income <= 150000:
        return 'от 140к до 150к'
    elif 150001 <= income <= 180000:
        return 'от 150к до 180к'
    elif 180001 <= income <= 200000:
        return 'от 180к до 200к'
    elif 200001 <= income <= 250000:
        return 'от 200к до 250к'
    else:
        return 'от 250к'

data['incom_group'] = data.total_income.apply(inc_group)

# %%
data.groupby('incom_group').debt.count().sort_values(ascending=False)
# Out:
# incom_group
# от 140к до 150к    2911
# от 250к            2812
# от 150к до 180к    2762
# от 100к до 120к    2382
# до 80к             2276
# от 200к до 250к    2253
# от 80к до 100к     2187
# от 180к до 200к    1356
# от 130к до 140к    1162
# от 120к до 130к    1098
# Name: debt, dtype: int64

# %%
def child(children):
    if children < 1:
        return 'бездетные'
    elif children == 1:
        return 'один'
    elif children == 2:
        return 'два'
    else:
        return 'три и больше'

data['child'] = data.children.apply(child)

# %%
data.groupby('child').debt.count().sort_values(ascending=False)
# Out:
# child
# бездетные       13888
# один             4814
# два              2118
# три и больше      379
# Name: debt, dtype: int64

# %% [markdown]
# ### Вывод

# %% [markdown]
# Категоризовали данные по доходу и количеству детей. Пригодится нам для анализа зависимостей в следующем шаге.

# %% [markdown]
# ### Шаг 3. Ответьте на вопросы

# %% [markdown]
# - Есть ли зависимость между наличием детей и возвратом кредита в срок?

# %%
data.groupby('child').debt.count().sort_values(ascending=False)
# Out:
# child
# бездетные       13888
# один             4814
# два              2118
# три и больше      379
# Name: debt, dtype: int64

# %%
(data.groupby('child').debt.sum() / data.groupby('child').debt.count()).sort_values(ascending=False)
# Out:
# child
# два             0.095373
# один            0.092439
# три и больше    0.081794
# бездетные       0.076469
# Name: debt, dtype: float64

# %%
(data.pivot_table(index='child', values='debt', aggfunc='sum')/data.pivot_table(index='child', values='debt', aggfunc='count')).sort_values('debt',ascending=False).reset_index()
# Out:
#           child      debt
# 0           два  0.095373
# 1          один  0.092439
# 2  три и больше  0.081794
# 3     бездетные  0.076469

# %% [markdown]
# ### Вывод

# %% [markdown]
# Чаще всего возвращают кредиты в срок **бездетные** заемщики, хуще всех у кого **один** или **два** ребенка. Про **многодетные** семьи толком ничего сказать не можем, потому что их на порядок меньше, но по тем данным что у нас есть, возвращают кредиты они хуже чем **бездетные** но лучше чем заемщики с **одним** или **двумя** детьми.

# %% [markdown]
# - Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %%
(data.groupby('family_status').debt.sum() / data.groupby('family_status').debt.count()).sort_values(ascending=False)
# Out:
# family_status
# Не женат / не замужем    0.098173
# гражданский брак         0.094083
# женат / замужем          0.076587
# в разводе                0.071249
# вдовец / вдова           0.066456
# Name: debt, dtype: float64

# %%
(data.pivot_table(index='family_status', values='debt', aggfunc='sum')/data.pivot_table(index='family_status', values='debt', aggfunc='count')).sort_values('debt',ascending=False).reset_index()
# Out:
#            family_status      debt
# 0  Не женат / не замужем  0.098173
# 1       гражданский брак  0.094083
# 2        женат / замужем  0.076587
# 3              в разводе  0.071249
# 4         вдовец / вдова  0.066456

# %% [markdown]
# ### Вывод

# %% [markdown]
# Не любят платить в срок **не женатые / не замужние** люди и люди живущие в **гражданском браке**. **Разведенные** и **вдовые** чаще платят в срок.

# %% [markdown]
# - Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %%
(data.groupby('incom_group').debt.sum() / data.groupby('incom_group').debt.count()).sort_values(ascending=False)
# Out:
# incom_group
# от 140к до 150к    0.092065
# от 150к до 180к    0.089790
# от 180к до 200к    0.088496
# от 120к до 130к    0.087432
# от 130к до 140к    0.085198
# от 100к до 120к    0.082704
# от 80к до 100к     0.082305
# до 80к             0.076450
# от 200к до 250к    0.072792
# от 250к            0.068990
# Name: debt, dtype: float64

# %%
(data.pivot_table(index='incom_group', values='debt', aggfunc='sum')/data.pivot_table(index='incom_group', values='debt', aggfunc='count')).sort_values('debt',ascending=False).reset_index()
# Out:
#        incom_group      debt
# 0  от 140к до 150к  0.092065
# 1  от 150к до 180к  0.089790
# 2  от 180к до 200к  0.088496
# 3  от 120к до 130к  0.087432
# 4  от 130к до 140к  0.085198
# 5  от 100к до 120к  0.082704
# 6   от 80к до 100к  0.082305
# 7           до 80к  0.076450
# 8  от 200к до 250к  0.072792
# 9          от 250к  0.068990

# %% [markdown]
# ### Вывод

# %% [markdown]
# Хуже всех платят в срок люди с доходом **от 120к до 200к**. Лучше всех платят категории с доходом **до 80к** и люди с доходом **от 200к**. Остальные средненько.

# %% [markdown]
# - Как разные цели кредита влияют на его возврат в срок?

# %% [markdown]
# Найдем количество не вернувших кредит в срок и поделим его на количество по категориям. Отсортирует по убыванию.

# %%
(data.groupby('purpose').debt.sum() / data.groupby('purpose').debt.count()).sort_values(ascending=False)
# Out:
# purpose
# автомобиль             0.094101
# образование            0.093340
# свадьба                0.080659
# строительство жилья    0.076964
# покупка жилья          0.073725
# ремонт жилья           0.057661
# Name: debt, dtype: float64

# %%
(data.pivot_table(index='purpose', values='debt', aggfunc='sum')/data.pivot_table(index='purpose', values='debt', aggfunc='count')).sort_values('debt',ascending=False).reset_index()
# Out:
#                purpose      debt
# 0           автомобиль  0.094101
# 1          образование  0.093340
# 2              свадьба  0.080659
# 3  строительство жилья  0.076964
# 4        покупка жилья  0.073725
# 5         ремонт жилья  0.057661

# %% [markdown]
# ### Вывод

# %% [markdown]
# Чаще всего не вовремя возвращают кредит, взявшие его на такие цели как **автомобиль** и **образование**, чаще всего возвращают кредит в срок люди взявшие деньги на **ремонт жилья**.

# %% [markdown]
# ### Шаг 4. Общий вывод

# %% [markdown]
# Что сделали: заполнили пропуски, выявили и исправили ошибки, удалили дубликаты, провели категоризацию и лемматизацию. Ответили на вопросы, зависимости своевременного возврата от количества детей, семейного положения, величины дохода и цели.
#
# Что можно было сделать еще: проанализировать зависимость своевременного возврата от возраста, отработанного времени и пола, убрать дублирующие столбцы с образованием и статуса семейного положения, добавить коммерческую недвижимость в цели кредита.
#
# Ну и вывод по цели проекта: будем давать кредиты разведенным заемщикам без детей с уровнем дохода либо больше 250к либо меньше 80к на ремонт или покупку жилья. Не будем давать кредиты не женатым / не замужним заемщикам с детьми с уровнем дохода от 120к до 200к на автомобиль или образование.
